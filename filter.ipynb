# %%
from boltiot import Bolt
import time
import re

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel('datafiltered.xls',sheet_name='Power_factor',header=None)
df.head()
df.drop(1,axis=0,inplace=True)
df.head()
# Out:
#                0              1              2              3              4  \
# 0  Power factor1  Power factor2  Power factor3  Power factor4  Power factor5
# 2       0.798077       0.864865       0.611111       0.949527       0.816667
# 3       0.842105       0.857143       0.416667       0.949227       0.833333
# 4       0.851064       0.857143       0.438596       0.923304            0.8
# 5        0.84375       0.864865       0.446429       0.947126       0.784314
#
#                5              6              7              8               9
# 0  Power factor6  Power factor7  Power factor8  Power factor9  Power factor10
# 2       0.983903              1       0.990566       0.857143               0
# 3       0.983871       0.985507       0.982906       0.872727               0
# 4       0.985075       0.956522       0.966942       0.872727               0
# 5       0.985597       0.926471       0.966942       0.857143               0

# %%
df.columns = df.iloc[0]

# %%
z = df.tail(50)
y = z.loc[z['Power factor1'] < 0.6]
print(y.shape)
# Out:
# (16, 10)

# %%
api_key = "445c90a1-ce8b-4621-99c1-ce356fb17eef"
device_id  = "BOLT6094114"
mybolt = Bolt(api_key, device_id)
response = mybolt.digitalWrite('0', 'HIGH')
res = mybolt.digitalWrite('1', 'HIGH')
print(response)
print(res)
time.sleep(5)
response = mybolt.digitalWrite('0','LOW')
res = mybolt.digitalWrite('1', 'LOW')
print (response)
print(res)
# Out:
# {"value": "Device is offline", "success": 0}
# {"value": "Device is offline", "success": 0}
# {"value": "Device is offline", "success": 0}
# {"value": "Device is offline", "success": 0}

# %%
vals = z['Power factor1'].tolist()
vals
for v in vals:
    if v>0.6:
        response = mybolt.digitalWrite('0', 'HIGH')
        print("Reading High")
        response = mybolt.digitalWrite('0', 'LOW')
    else:
        print("Reading Low")
    time.sleep(1.0)
# Out:
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading Low
# Reading Low
# Reading Low
# Reading Low
# Reading Low
# Reading Low
# Reading Low
# Reading Low
# Reading Low
# Reading Low
# Reading Low
# Reading Low
# Reading Low
# Reading Low
# Reading Low
# Reading Low
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High
# Reading High

# %%
df = pd.read_excel('hello.xls',sheet_name='Sheet1',header=None)

# %%
df.head()
df.columns = ['Date','Person1','Person2','Person3','Person4','Person5','Person6','Person7','Person8','Person9','Person10']

# %%
df[:][:20]
# Out:
#                     Date  Person1  Person2  Person3  Person4  Person5  \
# 0   01-May-2019 00:00:00    0.498    0.205    0.330    1.505    0.245
# 1   01-May-2019 00:15:00    0.400    0.190    0.210    2.150    0.250
# 2   01-May-2019 00:30:00    0.400    0.185    0.175    1.565    0.264
# 3   01-May-2019 00:45:00    0.405    0.175    0.175    2.060    0.240
# 4   01-May-2019 01:00:00    0.405    0.192    0.224    1.320    0.246
# 5   01-May-2019 01:15:00    0.410    0.170    0.231    1.730    0.246
# 6   01-May-2019 01:30:00    0.430    0.160    0.210    0.210    0.246
# 7   01-May-2019 01:45:00    0.460    0.160    0.105    0.090    0.252
# 8   01-May-2019 02:00:00    0.440    0.192    0.126    0.135    0.258
# 9   01-May-2019 02:15:00    0.320    0.155    0.105    1.200    0.252
# 10  01-May-2019 02:30:00    0.435    0.186    0.132    1.580    0.252
# 11  01-May-2019 02:45:00    0.430    0.160    0.168    1.715    0.246
# ...

# %%
date_time_cleaned = []
for d in df['Date']:
    result = re.match(r'\d\d-.*-\d\d\d\d (\d\d:\d\d)(:\d\d)',d)
    date_time_cleaned.append(result.group(1))

# %%
df['Date'] = date_time_cleaned

# %%
df.head()
# Out:
#     Date  Person1  Person2  Person3  Person4  Person5  Person6  Person7  \
# 0  00:00    0.498    0.205    0.330    1.505    0.245    2.445    0.345
# 1  00:15    0.400    0.190    0.210    2.150    0.250    2.440    0.340
# 2  00:30    0.400    0.185    0.175    1.565    0.264    2.310    0.330
# 3  00:45    0.405    0.175    0.175    2.060    0.240    2.395    0.315
# 4  01:00    0.405    0.192    0.224    1.320    0.246    2.325    0.220
#
#    Person8  Person9  Person10
# 0    0.525    0.240       0.0
# 1    0.575    0.240       0.0
# 2    0.585    0.240       0.0
# 3    0.585    0.240       0.0
# 4    0.595    0.245       0.0

# %%
df['Person1'][:94].sum()
# Out:
# 71.394

# %%
plt.scatter(df['Date'],df['Person1'])
